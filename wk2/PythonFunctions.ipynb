# %%
# Python Functions Exercise

"""
In this exercise, you'll practice creating and using functions in Python.
Follow the instructions for each task and implement the required functions.
"""
# Out:
# "\nIn this exercise, you'll practice creating and using functions in Python.\nFollow the instructions for each task and implement the required functions.\n"

# %%
# Task 1: Basic Function
# Create a function named 'hello_world' that prints "Hello, world!"
# Your code here


# Test Task 1
print("Task 1 Test:")
# Call your hello_world function
print()
# Out:
# Task 1 Test:

# %%
def hello_world():
    print("Hello, world!")

# %%
hello_world()
# Out:
# Hello, world!

# %%
# Task 2: Function with a Parameter
# Create a function named 'greet' that takes a name parameter 
# and prints a personalized greeting
# Your code here


# Test Task 2
print("Task 2 Test:")
# Call your greet function with different names
print()
# Out:
# Task 2 Test:

# %%
def greet(name):
    print(f"Hello, {name}! Welcome to the data science course")

# %%
greet("Todd")
# Out:
# Hello, Todd! Welcome to the data science course

# %%
# Task 3: Function with Multiple Parameters
# Create a function named 'calculate_area' that calculates the area of a rectangle
# It should take two parameters: length and width
# Your code here


# Test Task 3
print("Task 3 Test:")
# Call your calculate_area function with different dimensions
# Print the results
print()
# Out:
# Task 3 Test:

# %%
def calculate_area(length, width):
    area = length * width
    return area

# %%
result = calculate_area(10,5)
print(f"Area: {result}")
# Out:
# Area: 50

# %%
# Task 4: Function with Default Parameter Values
# Create a function named 'power' that calculates a number raised to a power
# The function should take two parameters: base and exponent (default to 2)
# Your code here


# Test Task 4
print("Task 4 Test:")
# Call your power function with and without specifying the exponent
# Print the results
print()
# Out:
# Task 4 Test:

# %%
def power(base, exponent=2):
    result = base ** exponent
    return result

# %%
squared = power(5)
print(squared)
# Out:
# 25

# %%
# Task 5: Function that Returns a Value
# Create a function named 'get_full_name' that combines first, middle, and last names
# The middle name should be optional
# Your code here


# Test Task 5
print("Task 5 Test:")
# Call your get_full_name function with and without a middle name
# Print the results
print()
# Out:
# Task 5 Test:

# %%
def get_full_name(first, last, middle=""):
    if middle:
        return f"{first} {middle} {last}"
    return f"{first} {last}"

# %%
full_name = get_full_name("Todd", "D", "Irwin")
print(full_name)
# Out:
# Todd Irwin D

# %%
# Task 6: Function Composition
# Create two functions:
# 1. 'celsius_to_fahrenheit' that converts a temperature from Celsius to Fahrenheit
# 2. 'fahrenheit_to_celsius' that converts a temperature from Fahrenheit to Celsius
# Formula: F = C * 9/5 + 32
# Your code here

def celsius_to_fahrenheit(celsius):
    return celsius * 9/5 + 32

def fahrenheit_to_celsius(fahrenheit):
    return (fahrenheit - 32) * 5/9

# Test Task 6
print("Task 6 Test:")
print(f"0°C is {celsius_to_fahrenheit(0)}°F")
print(f"100°C is {celsius_to_fahrenheit(100)}°F")
print(f"212°F is {fahrenheit_to_celsius(212)}°C")
print(f"32°F is {fahrenheit_to_celsius(32)}°C")
# Out:
# Task 6 Test:
# 0°C is 32.0°F
# 100°C is 212.0°F
# 212°F is 100.0°C
# 32°F is 0.0°C

# %%
# Task 7: Combining Functions and Conditionals
# Create a function named 'analyze_temperature' that:
# 1. Takes a temperature value and a unit ('C' or 'F')
# 2. Converts the temperature to the other unit
# 3. Returns a string describing if it's "freezing" (below 0°C), 
#    "cold" (0-15°C), "moderate" (15-25°C), or "hot" (above 25°C)
# Your code here

def celsius_to_fahrenheit(c):
    return c * 9/5 + 32

def fahrenheit_to_celsius(f):
    return (f - 32) * 5/9

def analyze_temperature(temp, unit):
    if unit.upper() == 'F':
        temp_c = fahrenheit_to_celsius(temp)
        other_temp = temp
        other_unit = 'F'
    else:
        temp_c = temp
        other_temp = celsius_to_fahrenheit(temp)
        other_unit = 'F' if unit.upper() == 'C' else 'C' 

    if temp_c < 0:
        description = "freezing"
    elif 0 <= temp_c <= 15:
        description = "cold"
    elif 15 < temp_c <= 25:
        description = "moderate"
    else:
        description = "hot"

    return f"{temp}°{unit.upper()} is {description} (approx. {other_temp:.1f}°{other_unit})"

# Test Task 7
print("Task 7 Test:")
print(analyze_temperature(20, 'F'))   # Freezing
print(analyze_temperature(12, 'C'))   # Cold
print(analyze_temperature(82, 'F'))   # Moderate
print(analyze_temperature(25, 'C'))   # Hot
print()
# Out:
# Task 7 Test:
# 20°F is freezing (approx. 20.0°F)
# 12°C is cold (approx. 53.6°F)
# 82°F is hot (approx. 82.0°F)
# 25°C is moderate (approx. 77.0°F)

# %%
# Task 8: Function with Variable Arguments
# Create a function named 'calculate_average' that:
# 1. Accepts any number of numeric arguments
# 2. Returns the average of all numbers provided
# Your code here

def calculate_average(*numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count

 
# Test Task 8
print("Task 8 Test:")
# Call your calculate_average function with different sets of numbers
# Print the results
print(f"Average of (100, 25, 80, 50): {calculate_average(100, 25, 80, 50)}")
print(f"Average of (50, 150, 100): {calculate_average(50, 150, 100)}")
print()
# Out:
# Task 8 Test:
# Average of (100, 25, 80, 50): 63.75
# Average of (50, 150, 100): 100.0

# %%
# Task 9: Advanced Challenge - Student Grade Function
# Create a function named 'calculate_final_grade' that:
# 1. Takes a student's name and any number of assignment scores
# 2. Calculates the average score
# 3. Determines the letter grade based on the average (A: 90+, B: 80-89, C: 70-79, D: 60-69, F: <60)
# 4. Returns a formatted string with the student's name, average score, and letter grade
# Your code here

def calculate_final_grade(student_name, *grades):
    GPA = sum(grades) / len(grades)
    
    if grades < 60:
        description = "F"
    elif 60 <= grades <= 69:
        description = "D"
    elif 70 < grades <= 79:
        description = "C"
    elif 80 < grades <= 89:
        description = "B"
    else:
        description = "A"

    return f"Student: {student_name} Average: {GPA} Letter Grade: {description}"

def calculate_final_grade(student_name, *scores):
    # 1. Handle cases with no scores to avoid division by zero
    if not scores:
        return f"Student {student_name} has no scores recorded."
    
    # 2. Calculate the average
    average_score = sum(scores) / len(scores)
    
    # 3. Determine the letter grade using conditional logic
    if average_score >= 90:
        letter_grade = 'A'
    elif average_score >= 80:
        letter_grade = 'B'
    elif average_score >= 70:
        letter_grade = 'C'
    elif average_score >= 60:
        letter_grade = 'D'
    else:
        letter_grade = 'F'
    
    # 4. Return formatted string (rounded to 1 decimal place)
    return f"Student: {student_name} | Average: {average_score:.1f} | Grade: {letter_grade}"

# Test Task 9
print("Task 9 Test:")
print(calculate_final_grade("Brittney", 95, 88, 92)) # Test with multiple scores
print(calculate_final_grade("Anura", 70, 85, 78))    # Test with different scores
print(calculate_final_grade("Milton", 100, 98))      # Test with instructor scores
print()
pass


# Test Task 9
print("Task 9 Test:")
# Test with different student names and scores
# Print the results
print(f"{calculate_final_grade("Todd", 25, 80, 50)}")

print()
# Out:
# Task 9 Test:
# Student: Brittney | Average: 91.7 | Grade: A
# Student: Anura | Average: 77.7 | Grade: C
# Student: Milton | Average: 99.0 | Grade: A
#
# Task 9 Test:
# Student: Todd | Average: 51.7 | Grade: F
